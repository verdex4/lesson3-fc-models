# %%
# Создайте и обучите модели с различным количеством слоев:
# - 1 слой (линейный классификатор)
# - 2 слоя (1 скрытый)
# - 3 слоя (2 скрытых)
# - 5 слоев (4 скрытых)
# - 7 слоев (6 скрытых)
# 
# Для каждого варианта:
# - Сравните точность на train и test
# - Визуализируйте кривые обучения
# - Проанализируйте время обучения

# %%
from utils.experiment_utils import test_different_depth, test_overfitting_with_different_depth
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
test_different_depth(dataset='mnist')
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 61.76it/s]
# Epoch 1/5:
# Train Loss: 0.3916, Train Acc: 0.8882
# Test Loss: 0.2907, Test Acc: 0.9164
# --------------------------------------------------
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 66.50it/s]
# Epoch 2/5:
# Train Loss: 0.2931, Train Acc: 0.9167
# Test Loss: 0.2841, Test Acc: 0.9194
# --------------------------------------------------
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 67.65it/s]
# Epoch 3/5:
# Train Loss: 0.2828, Train Acc: 0.9206
# Test Loss: 0.2741, Test Acc: 0.9228
# --------------------------------------------------
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 64.47it/s]
# Epoch 4/5:
# Train Loss: 0.2759, Train Acc: 0.9221
# ...

# %%
# Исследуйте влияние глубины на переобучение:
# - Постройте графики train/test accuracy по эпохам
# - Определите оптимальную глубину для каждого датасета
# - Добавьте Dropout и BatchNorm, сравните результаты
# - Проанализируйте, когда начинается переобучение

# %%
test_overfitting_with_different_depth()
# Out:
# DATASET: MNIST
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 71.72it/s]
# Epoch 1/5:
# Train Loss: 0.3951, Train Acc: 0.8867
# Test Loss: 0.2959, Test Acc: 0.9169
# --------------------------------------------------
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 70.19it/s]
# Epoch 2/5:
# Train Loss: 0.2944, Train Acc: 0.9162
# Test Loss: 0.2784, Test Acc: 0.9224
# --------------------------------------------------
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 65.16it/s]
# Epoch 3/5:
# Train Loss: 0.2823, Train Acc: 0.9214
# Test Loss: 0.2724, Test Acc: 0.9244
# --------------------------------------------------
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 70.63it/s]
# Epoch 4/5:
# Train Loss: 0.2756, Train Acc: 0.9225
# ...
